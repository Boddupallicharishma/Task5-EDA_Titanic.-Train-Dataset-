# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6e43dcb24b26> in <cell line: 0>()
#      17 # 2. Load Dataset
#      18 # ----------------------------
# ---> 19 df = pd.read_csv('customer_segmentation_sample.csv')
#      20
#      21 # ----------------------------
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV
df = pd.read_csv('customer_segmentation_sample.csv')

# Basic Info
print("\n🔍 Dataset Info:")
print(df.info())

print("\n🧮 Missing Values:")
print(df.isnull().sum())

print("\n📊 Descriptive Statistics:")
print(df.describe())

# Univariate Analysis
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution")
plt.show()

# Bivariate Analysis
sns.boxplot(x='Gender', y='Spending_Score', data=df)
plt.title("Spending Score by Gender")
plt.show()

sns.barplot(x='Membership_Level', y='Annual_Income_k$', data=df)
plt.title("Income by Membership Level")
plt.xticks(rotation=45)
plt.show()

# Correlation Heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues')
plt.title("Correlation Heatmap")
plt.show()

# Summary
print("\n📝 Insights:")
print("- Younger customers tend to have higher spending scores.")
print("- Gold and Platinum members have moderate to high incomes.")
print("- Gender may influence spending behavior.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-97a087e6a3e8> in <cell line: 0>()
#       4
#       5 # Load CSV
# ----> 6 df = pd.read_csv('customer_segmentation_sample.csv')
#       7
#       8 # Basic Info
#
# ...

# %%
from google.colab import files
uploaded=files.upload()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('titanic_sample.csv')
print("\n🔍 Dataset Info:")
print(df.info())

print("\n🧮 Missing Values:")
print(df.isnull().sum())

print("\n📊 Descriptive Statistics:")
print(df.describe())
sns.histplot(df['Age'].dropna(), kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()
sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age vs Survival")
plt.show()

sns.barplot(x='Pclass', y='Fare', hue='Survived', data=df)
plt.title("Fare by Class and Survival")
plt.show()
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
print("\n📝 Summary of Insights:")
print("- Younger passengers had higher chances of survival.")
print("- 1st class passengers paid higher fares and had better survival rates.")
print("- Females and children survived more often.")
print("- Fare and Pclass show strong correlation.")
# Out:
#      <input type="file" id="files-2919c9b6-0bce-4b12-8f1f-0926086da0d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2919c9b6-0bce-4b12-8f1f-0926086da0d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
